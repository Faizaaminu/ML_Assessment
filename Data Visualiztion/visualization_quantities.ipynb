# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
birds=pd.read_csv(r"C:\Users\MINE\OneDrive\Desktop\ArewaDS-Machine-Learning\data\birds.csv")
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.tail()
# Out:
#                 Name      ScientificName          Category          Order  \
# 438    Blue grosbeak  Passerina caerulea  Cardinals/Allies  Passeriformes
# 439   Lazuli bunting    Passerina amoena  Cardinals/Allies  Passeriformes
# 440   Indigo bunting    Passerina cyanea  Cardinals/Allies  Passeriformes
# 441  Painted bunting     Passerina ciris  Cardinals/Allies  Passeriformes
# 442       Dickcissel     Spiza americana  Cardinals/Allies  Passeriformes
#
#            Family      Genus ConservationStatus  MinLength  MaxLength  \
# 438  Cardinalidae  Passerina                 LC       14.0       19.0
# 439  Cardinalidae  Passerina                 LC       13.0       15.0
# 440  Cardinalidae  Passerina                 LC       11.5       15.0
# 441  Cardinalidae  Passerina                 LC       12.0       14.0
# 442  Cardinalidae      Spiza                 LC       14.0       16.0
#
#      MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# ...

# %%
birds.shape
# Out:
# (443, 13)

# %%
birds.columns  #Display columns name
# Out:
# Index(['Name', 'ScientificName', 'Category', 'Order', 'Family', 'Genus',
#        'ConservationStatus', 'MinLength', 'MaxLength', 'MinBodyMass',
#        'MaxBodyMass', 'MinWingspan', 'MaxWingspan'],
#       dtype='object')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
birds.isnull().sum()
# Out:
# Name                  0
# ScientificName        0
# Category              0
# Order                 0
# Family                0
# Genus                 0
# ConservationStatus    0
# MinLength             0
# MaxLength             0
# MinBodyMass           0
# MaxBodyMass           0
# MinWingspan           0
# MaxWingspan           0
# dtype: int64

# %%
birds.Category.nunique()
# Out:
# 60

# %%
birds.Category.value_counts().head()
# Out:
# Category
# Ducks/Geese/Waterfowl    45
# New World warblers       41
# Sandpipers/Allies        34
# Gulls/Terns/Skimmers     28
# New World sparrows       26
# Name: count, dtype: int64

# %%
birds.Category.value_counts().head(1).index[0]
# Out:
# 'Ducks/Geese/Waterfowl'

# %%
birds.Order.value_counts()
# Out:
# Order
# Passeriformes        195
# Charadriiformes       78
# Anseriformes          45
# Pelecaniformes        17
# Accipitriformes       16
# Piciformes            12
# Strigiformes          12
# Gruiformes            10
# Galliformes           10
# Apodiformes            9
# Columbiformes          8
# Podicipediformes       6
# Falconformes           6
# Caprimulgiformes       4
# Gaviiformes            4
# Suliformes             3
# Cuculiformes           3
# Cathartiformes         2
# Coraciiformes          1
# Ciconiiformes          1
# Procellariiformes      1
# Name: count, dtype: int64

# %%
birds.describe()
# Out:
#         MinLength   MaxLength  MinBodyMass   MaxBodyMass  MinWingspan  \
# count  443.000000  443.000000   443.000000    443.000000   443.000000
# mean    28.536682   35.441986   327.938262    667.009752    58.557901
# std     20.319887   27.539772   779.680106   1655.682564   104.602369
# min      7.000000    8.900000     2.000000      3.000000     8.000000
# 25%     13.750000   16.000000    18.000000     28.000000    23.000000
# 50%     20.500000   25.000000    55.000000     89.000000    38.000000
# 75%     39.000000   46.000000   332.000000    593.000000    72.750000
# max    138.000000  180.000000  9200.000000  14300.000000  1800.000000
#
#        MaxWingspan
# count   443.000000
# mean     67.524492
# std     126.673177
# min      10.600000
# 25%      25.000000
# 50%      42.000000
# 75%      83.000000
# max    2300.000000

# %%
print(birds.groupby("Family")["MaxWingspan"].max())
# Out:
# Family
# Accipitridae         2300.0
# Alaudidae              34.0
# Alcedinidae            58.0
# Alcidae                58.0
# Anatidae              250.0
# Apodidae               35.5
# Ardeidae              201.0
# Bombycillidae          35.5
# Calcariidae            38.0
# Caprimulgidae          66.0
# Cardinalidae           33.0
# Cathartidae           183.0
# Certhiidae             20.0
# Charadriidae           83.0
# Ciconiidae            180.0
# Cinclidae              23.0
# Columbidae             72.0
# Corvidae              150.0
# Cuculidae              46.0
# Falconidae           1100.0
# Fregatidae            244.0
# Fringillidae           36.0
# Gaviidae              160.0
# Gruidae               230.0
# Hirundinidae           41.0
# Icteridae              58.0
# Laniidae               35.0
# Laridae               170.0
# Mimidae                38.0
# Motacillidae           25.4
# Muscicapidae           32.0
# Odontophoridae         38.0
# Pandionidae           180.0
# ...

# %% [markdown]
# Let's visualize these birds' wingspan by showing a very basic line plot

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
wingspan = birds.MaxWingspan 
wingspan.plot()
# Out:
# <Axes: title={'center': 'Max Wingspan in Centimeters'}, xlabel='Birds', ylabel='Wingspan (CM)'>

# %% [markdown]
# Show the birds' names correlated to their wingspan

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.xticks(rotation=45)
x = birds['Name'] 
y = birds['MaxWingspan']

plt.plot(x, y)

plt.show()

# %%
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(birds['Name'],birds['MinWingspan'], label='MinWingspan', marker='o')
plt.title('Wingspan Range per Bird')
plt.xlabel('Name')
plt.ylabel('Wingspan (cm)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(birds['Category'],birds['MinWingspan'], label='MinWingspan', marker='o')
plt.title('Wingspan Range per Bird')
plt.xlabel('Category')
plt.ylabel('Wingspan (cm)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
top_birds=birds.sort_values(by='MaxBodyMass', ascending=False).head(10)
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.tail()
# Out:
#                 Name      ScientificName          Category          Order  \
# 438    Blue grosbeak  Passerina caerulea  Cardinals/Allies  Passeriformes
# 439   Lazuli bunting    Passerina amoena  Cardinals/Allies  Passeriformes
# 440   Indigo bunting    Passerina cyanea  Cardinals/Allies  Passeriformes
# 441  Painted bunting     Passerina ciris  Cardinals/Allies  Passeriformes
# 442       Dickcissel     Spiza americana  Cardinals/Allies  Passeriformes
#
#            Family      Genus ConservationStatus  MinLength  MaxLength  \
# 438  Cardinalidae  Passerina                 LC       14.0       19.0
# 439  Cardinalidae  Passerina                 LC       13.0       15.0
# 440  Cardinalidae  Passerina                 LC       11.5       15.0
# 441  Cardinalidae  Passerina                 LC       12.0       14.0
# 442  Cardinalidae      Spiza                 LC       14.0       16.0
#
#      MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# ...

# %%
plt.figure(figsize=(14, 10))
plt.plot(top_birds['Name'],top_birds
['MinWingspan'], label='MinWingspan', marker='o')
plt.plot(top_birds['Name'],top_birds['MaxWingspan'], label='MaxWingspan', marker='o')
plt.title('Wingspan Range of Top 10 Heaviest Birds')
plt.ylabel('Wingspan (cm)')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()

# %%
Category_mass=birds.groupby('Category')
['MaxBodyMass']
Category_mass.plot(kind='bar', color='skyblue', figsize=(10, 5))
plt.title('Average Maximum Body Mass per Birds Category')
plt.ylabel('MaxBodyMass (g)')
plt.xlabel('Category')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(top_birds['Name'], top_birds['MaxBodyMass'])
plt.title('Top 10 Birds by Max Body Mass')
plt.ylabel('MaxBodyMass (g)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(birds['Name'],birds['MaxBodyMass'])
plt.title(' Birds by Max Body Mass')
plt.ylabel('MaxBodyMass (g)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(birds['MaxLength'], birds['MaxWingspan'], c='green', alpha=0.7)
plt.title('Max Length vs Max Wingspan')
plt.xlabel('MaxLength (cm)')
plt.ylabel('MaxWingspan (cm)')
#plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
plt.Figure(figsize=(10,6))
sns.barplot(data=birds,
            x='ConservationStatus', y='MaxWingspan', ci=None, palette='viridis', hue='ConservationStatus')
plt.title('Average MaxWingspan by Conservation Status', fontsize=14)
plt.xlabel('ConservationStatus')
ylabel=('Average MaxWingspan (cm)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\MINE\AppData\Local\Temp\ipykernel_12240\2646302424.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=birds,

# %%
birds.ConservationStatus.nunique()
# Out:
# 6

# %%
plt.figure(figsize=(12,8))
plt.title('Max Length in Centimeters')
plt.ylabel('length (CM)')
plt.xlabel('Birds')
length = birds.MaxLength 
length.plot()
# Out:
# <Axes: title={'center': 'Max Length in Centimeters'}, xlabel='Birds', ylabel='length (CM)'>

# %% [markdown]
# Label the birds whose wingspan is particularly large and are probably outliers

# %% [markdown]
# Remove those outliers and redraw the wingspan

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)
for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    if birds['Name'][i] not in ['Bald eagle', 'Prairie falcon']:
        plt.plot(x, y, 'bo')
plt.show()

# %%
category_count = birds.value_counts(birds['Category'].values, sort=True)
plt.rcParams['figure.figsize'] = [6, 12]
category_count.plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# Show the categories with their maxlength displayed per category

# %%
maxlength = birds['MaxLength']
plt.barh(y=birds['Category'], width=maxlength)
plt.rcParams['figure.figsize'] = [6, 12]
plt.show()

# %%
top_birds=birds.sort_values(by='Category', ascending=False).head(10)
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %% [markdown]
# Superimpose the birds minimum and maximum lengths per category

# %%
plt.figure(figsize=(12,8))
minLength =birds ['MinLength']
maxLength = birds['MaxLength']
category = birds['Category']

plt.barh(category, maxLength)
plt.barh(category, minLength)

plt.show()

# %%
#import matplotlib.pyplot as plt

birds.set_index("Family")[["MinLength", "MaxLength"]].plot(kind="bar")
plt.title("MaxWingspan")
plt.ylabel("MaxWingspan")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
